# %% [markdown]
# # Topic Modeling and t-SNE Visualization
# Ref:
# https://shuaiw.github.io/2016/12/22/topic-modeling-and-tsne-visualzation.html

# %% [markdown]
# **Topic models are a suite of algorithms/statistical models that uncover the hidden topics in a collection of documents.**
# Popular topic modeling algorithms incldue latent semantic analysis (LSA), hierarchical Dirichlet process (HDP), and latent Dirichlet allocation (LDA), among which LDA has shown great results in practice and therefore been widely adopted. <br>
# **gensim library:**  Great for modeling topics

# %% [markdown]
# ## t-SNE
# t-SNE, or t-distributed stochastic neighbor embedding, is a dimensionality reduction algorithm for high-dimensional data visualization. This is partly to mitigate the fact that human cannot (at least not now) perceive vector space that is beyond 3-D.

# %%
#Loading data
import os
import argparse

from sklearn.datasets import fetch_20newsgroups

# we only want to keep the body of the documents!
remove = ('headers', 'footers', 'quotes')

# fetch train and test data
newsgroups_train = fetch_20newsgroups(subset='train', remove=remove)
newsgroups_test = fetch_20newsgroups(subset='test', remove=remove)

# a list of 18,846 cleaned news in string format
# only keep letters & make them all lower case

# %%
 news = [' '.join(filter(None, raw.lower().split())) for raw in
          newsgroups_train.data + newsgroups_test.data]

# %% [markdown]
# ### Training an LDA model

# %%
import lda # if you get error pip install lda

from sklearn.feature_extraction.text import CountVectorizer

n_topics = 20 # number of topics
n_iter = 500 # number of iterations

# vectorizer: ignore English stopwords & words that occur less than 5 times
cvectorizer = CountVectorizer(min_df=5, stop_words='english')
cvz = cvectorizer.fit_transform(news)

# train an LDA model
lda_model = lda.LDA(n_topics=n_topics, n_iter=n_iter)
X_topics = lda_model.fit_transform(cvz)
# Out:
# INFO:lda:n_documents: 18846
# INFO:lda:vocab_size: 24164
# INFO:lda:n_words: 1721127
# INFO:lda:n_topics: 20
# INFO:lda:n_iter: 500
# WARNING:lda:all zero row in document-term matrix found
# /Users/mk194903/anaconda3/lib/python3.6/site-packages/lda/utils.py:55: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if sparse and not np.issubdtype(doc_word.dtype, int):
# INFO:lda:<0> log likelihood: -21729674
# INFO:lda:<10> log likelihood: -15811330
# INFO:lda:<20> log likelihood: -15020541
# INFO:lda:<30> log likelihood: -14774572
# INFO:lda:<40> log likelihood: -14644561
# INFO:lda:<50> log likelihood: -14557450
# INFO:lda:<60> log likelihood: -14489942
# INFO:lda:<70> log likelihood: -14443270
# INFO:lda:<80> log likelihood: -14411212
# INFO:lda:<90> log likelihood: -14390832
# INFO:lda:<100> log likelihood: -14369004
# INFO:lda:<110> log likelihood: -14358385
# INFO:lda:<120> log likelihood: -14345462
# INFO:lda:<130> log likelihood: -14340922
# INFO:lda:<140> log likelihood: -14332530
# INFO:lda:<150> log likelihood: -14329208
# INFO:lda:<160> log likelihood: -14324311
# INFO:lda:<170> log likelihood: -14319266
# INFO:lda:<180> log likelihood: -14317531
# INFO:lda:<190> log likelihood: -14316935
# INFO:lda:<200> log likelihood: -14312411
# INFO:lda:<210> log likelihood: -14308548
# INFO:lda:<220> log likelihood: -14305962
# INFO:lda:<230> log likelihood: -14304572
# INFO:lda:<240> log likelihood: -14303072
# INFO:lda:<250> log likelihood: -14302245
# INFO:lda:<260> log likelihood: -14297393
# INFO:lda:<270> log likelihood: -14297195
# INFO:lda:<280> log likelihood: -14294774
# INFO:lda:<290> log likelihood: -14294375
# INFO:lda:<300> log likelihood: -14294760
# INFO:lda:<310> log likelihood: -14294751
# INFO:lda:<320> log likelihood: -14294073
# INFO:lda:<330> log likelihood: -14291646
# INFO:lda:<340> log likelihood: -14290221
# INFO:lda:<350> log likelihood: -14290537
# INFO:lda:<360> log likelihood: -14289091
# INFO:lda:<370> log likelihood: -14290477
# INFO:lda:<380> log likelihood: -14290129
# INFO:lda:<390> log likelihood: -14290281
# INFO:lda:<400> log likelihood: -14286144
# INFO:lda:<410> log likelihood: -14286749
# INFO:lda:<420> log likelihood: -14288330
# INFO:lda:<430> log likelihood: -14287450
# INFO:lda:<440> log likelihood: -14286443
# INFO:lda:<450> log likelihood: -14286033
# INFO:lda:<460> log likelihood: -14285152
# INFO:lda:<470> log likelihood: -14285962
# INFO:lda:<480> log likelihood: -14286966
# INFO:lda:<490> log likelihood: -14284696
# INFO:lda:<499> log likelihood: -14284848

# %%
#add a threshold factor that would help filter out unconfident topic assignments. Other wise visualization will be busy

threshold = 0.5
_idx = np.amax(X_topics, axis=1) > threshold  # idx of doc that above the threshold
X_topics = X_topics[_idx]

# %% [markdown]
# ### Reducing to 2-D with t-SNE

# %%
from sklearn.manifold import TSNE

# a t-SNE model
# angle value close to 1 means sacrificing accuracy for speed
# pca initializtion usually leads to better results 
tsne_model = TSNE(n_components=2, verbose=1, random_state=0, angle=.99, init='pca')

# 20-D -> 2-D
tsne_lda = tsne_model.fit_transform(X_topics)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 9129 samples in 0.007s...
# [t-SNE] Computed neighbors for 9129 samples in 3.049s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 9129
# [t-SNE] Computed conditional probabilities for sample 2000 / 9129
# [t-SNE] Computed conditional probabilities for sample 3000 / 9129
# [t-SNE] Computed conditional probabilities for sample 4000 / 9129
# [t-SNE] Computed conditional probabilities for sample 5000 / 9129
# [t-SNE] Computed conditional probabilities for sample 6000 / 9129
# [t-SNE] Computed conditional probabilities for sample 7000 / 9129
# [t-SNE] Computed conditional probabilities for sample 8000 / 9129
# [t-SNE] Computed conditional probabilities for sample 9000 / 9129
# [t-SNE] Computed conditional probabilities for sample 9129 / 9129
# [t-SNE] Mean sigma: 0.059164
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 68.591118
# [t-SNE] KL divergence after 1000 iterations: 1.089022

# %%
X_topics
# Out:
# array([[0.00263158, 0.13421053, 0.00263158, ..., 0.00263158, 0.00263158,
#         0.00263158],
#        [0.02156863, 0.00196078, 0.00196078, ..., 0.02156863, 0.06078431,
#         0.00196078],
#        [0.721875  , 0.003125  , 0.003125  , ..., 0.003125  , 0.003125  ,
#         0.065625  ],
#        ...,
#        [0.10625   , 0.00208333, 0.00208333, ..., 0.00208333, 0.00208333,
#         0.10625   ],
#        [0.00169492, 0.00169492, 0.00169492, ..., 0.00169492, 0.08644068,
#         0.00169492],
#        [0.003125  , 0.003125  , 0.003125  , ..., 0.003125  , 0.003125  ,
#         0.003125  ]])

# %%
X_topics.shape
# Out:
# (9129, 20)

# %% [markdown]
# ## Visualzing groups and their keywords

# %%
#First we do some setup work (import classes & functions, set params, etc.)
import numpy as np
import bokeh.plotting as bp
from bokeh.plotting import save
from bokeh.plotting import figure, show
from bokeh.io import  output_notebook
from bokeh.models import HoverTool

n_top_words = 5 # number of keywords we show

# 20 colors
colormap = np.array([
    "#1f77b4", "#aec7e8", "#ff7f0e", "#ffbb78", "#2ca02c",
    "#98df8a", "#d62728", "#ff9896", "#9467bd", "#c5b0d5",
    "#8c564b", "#c49c94", "#e377c2", "#f7b6d2", "#7f7f7f",
    "#c7c7c7", "#bcbd22", "#dbdb8d", "#17becf", "#9edae5"
])

# %%
#Then we find the most likely topic for each news
_lda_keys = []
for i in range(X_topics.shape[0]):
  _lda_keys +=  X_topics[i].argmax(),

# %%
# get top words for each topic
topic_summaries = []
topic_word = lda_model.topic_word_  # all topic words
vocab = cvectorizer.get_feature_names()
for i, topic_dist in enumerate(topic_word):
  topic_words = np.array(vocab)[np.argsort(topic_dist)][:-(n_top_words + 1):-1] # get!
  topic_summaries.append(' '.join(topic_words)) # append!

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4143bd77-d332-4b22-ac66-a18ef7b9c99b">Loading BokehJS ...</span>
#     </div>

# %%
# plot the news (each point representing one news)
title = '20 newsgroups LDA viz'
num_example = len(X_topics)

plot_lda = bp.figure(plot_width=1400, plot_height=1100,
                    title=title,
                    tools="pan,wheel_zoom,box_zoom,reset,hover,previewsave",
                    x_axis_type=None, y_axis_type=None, min_border=1)

plot_lda.scatter(x=tsne_lda[:, 0], y=tsne_lda[:, 1],
                color=colormap[_lda_keys[:num_example]])
# Out:
# bokeh.models.renderers.GlyphRenderer(
#     id='4e297ab8-67b2-4c77-99c8-34c66d21621b',
#     data_source=bokeh.models.sources.ColumnDataSource(
#         id='c38d1f07-8111-4d7d-9c0b-68f4669e027f',
#         callback=None,
#         data={'y': {'__ndarray__': '...',
#           'shape': (9129,),
#           'dtype': 'float32'},
#          'x': {'__ndarray__': '...',
#           'shape': (9129,),
#           'dtype': 'float32'},
#          'line_color': ['#7f7f7f',
#           '#9467bd',
#           '#1f77b4',
#           '#17becf',
#           '#9467bd',
#           '#8c564b',
#           '#c49c94',
#           '#f7b6d2',
#           '#8c564b',
#           '#e377c2',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#bcbd22',
#           '#98df8a',
#           '#9edae5',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#e377c2',
#           '#8c564b',
#           '#7f7f7f',
#           '#9467bd',
#           '#8c564b',
#           '#98df8a',
#           '#9467bd',
#           '#bcbd22',
#           '#7f7f7f',
#           '#8c564b',
#           '#c49c94',
#           '#17becf',
#           '#8c564b',
#           '#98df8a',
#           '#7f7f7f',
#           '#e377c2',
#           '#17becf',
#           '#bcbd22',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#9467bd',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#7f7f7f',
#           '#9467bd',
#           '#9467bd',
#           '#17becf',
#           '#17becf',
#           '#7f7f7f',
#           '#ffbb78',
#           '#9467bd',
#           '#bcbd22',
#           '#9467bd',
#           '#9467bd',
#           '#7f7f7f',
#           '#8c564b',
#           '#ffbb78',
#           '#7f7f7f',
#           '#e377c2',
#           '#f7b6d2',
#           '#9467bd',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#e377c2',
#           '#7f7f7f',
#           '#8c564b',
#           '#e377c2',
#           '#7f7f7f',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#98df8a',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#f7b6d2',
#           '#bcbd22',
#           '#e377c2',
#           '#c7c7c7',
#           '#9467bd',
#           '#17becf',
#           '#98df8a',
#           '#2ca02c',
#           '#ffbb78',
#           '#7f7f7f',
#           '#d62728',
#           '#98df8a',
#           '#c49c94',
#           '#7f7f7f',
#           '#98df8a',
#           '#e377c2',
#           '#f7b6d2',
#           '#f7b6d2',
#           '#e377c2',
#           '#f7b6d2',
#           '#8c564b',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#e377c2',
#           '#f7b6d2',
#           '#9467bd',
#           '#e377c2',
#           '#ffbb78',
#           '#9467bd',
#           '#9467bd',
#           '#9467bd',
#           '#f7b6d2',
#           '#f7b6d2',
#           '#e377c2',
#           '#ff7f0e',
#           '#9467bd',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#9467bd',
#           '#e377c2',
#           '#9edae5',
#           '#e377c2',
#           '#9edae5',
#           '#e377c2',
#           '#e377c2',
#           '#9467bd',
#           '#9467bd',
#           '#c7c7c7',
#           '#9467bd',
#           '#98df8a',
#           '#9467bd',
#           '#ff7f0e',
#           '#98df8a',
#           '#9467bd',
#           '#1f77b4',
#           '#dbdb8d',
#           '#ff7f0e',
#           '#c7c7c7',
#           '#9edae5',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#bcbd22',
#           '#7f7f7f',
#           '#8c564b',
#           '#9467bd',
#           '#dbdb8d',
#           '#f7b6d2',
#           '#9467bd',
#           '#f7b6d2',
#           '#8c564b',
#           '#e377c2',
#           '#e377c2',
#           '#98df8a',
#           '#e377c2',
#           '#f7b6d2',
#           '#8c564b',
#           '#7f7f7f',
#           '#e377c2',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#98df8a',
#           '#9467bd',
#           '#9467bd',
#           '#8c564b',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#17becf',
#           '#8c564b',
#           '#e377c2',
#           '#e377c2',
#           '#e377c2',
#           '#17becf',
#           '#c7c7c7',
#           '#ffbb78',
#           '#7f7f7f',
#           '#17becf',
#           '#9467bd',
#           '#c7c7c7',
#           '#9467bd',
#           '#9467bd',
#           '#e377c2',
#           '#1f77b4',
#           '#98df8a',
#           '#c7c7c7',
#           '#ffbb78',
#           '#9467bd',
#           '#f7b6d2',
#           '#e377c2',
#           '#98df8a',
#           '#8c564b',
#           '#9467bd',
#           '#c7c7c7',
#           '#9467bd',
#           '#1f77b4',
#           '#bcbd22',
#           '#9467bd',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#17becf',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#17becf',
#           '#e377c2',
#           '#9467bd',
#           '#8c564b',
#           '#17becf',
#           '#e377c2',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#8c564b',
#           '#e377c2',
#           '#ffbb78',
#           '#8c564b',
#           '#17becf',
#           '#8c564b',
#           '#8c564b',
#           '#8c564b',
#           '#dbdb8d',
#           '#98df8a',
#           '#9467bd',
#           '#7f7f7f',
#           '#e377c2',
#           '#9467bd',
#           '#17becf',
#           '#98df8a',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#17becf',
#           '#e377c2',
#           '#9467bd',
#           '#17becf',
#           '#e377c2',
#           '#ff7f0e',
#           '#17becf',
#           '#98df8a',
#           '#17becf',
#           '#e377c2',
#           '#7f7f7f',
#           '#17becf',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#e377c2',
#           '#f7b6d2',
#           '#c7c7c7',
#           '#bcbd22',
#           '#98df8a',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#e377c2',
#           '#1f77b4',
#           '#c7c7c7',
#           '#9467bd',
#           '#17becf',
#           '#9467bd',
#           '#aec7e8',
#           '#c7c7c7',
#           '#98df8a',
#           '#e377c2',
#           '#c5b0d5',
#           '#7f7f7f',
#           '#9467bd',
#           '#2ca02c',
#           '#bcbd22',
#           '#e377c2',
#           '#bcbd22',
#           '#9467bd',
#           '#2ca02c',
#           '#f7b6d2',
#           '#9467bd',
#           '#bcbd22',
#           '#7f7f7f',
#           '#9467bd',
#           '#7f7f7f',
#           '#98df8a',
#           '#9467bd',
#           '#c49c94',
#           '#f7b6d2',
#           '#e377c2',
#           '#17becf',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#9467bd',
#           '#98df8a',
#           '#8c564b',
#           '#bcbd22',
#           '#7f7f7f',
#           '#e377c2',
#           '#e377c2',
#           '#9467bd',
#           '#ff7f0e',
#           '#f7b6d2',
#           '#9467bd',
#           '#aec7e8',
#           '#7f7f7f',
#           '#9467bd',
#           '#2ca02c',
#           '#8c564b',
#           '#f7b6d2',
#           '#e377c2',
#           '#9edae5',
#           '#7f7f7f',
#           '#8c564b',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#e377c2',
#           '#8c564b',
#           '#8c564b',
#           '#e377c2',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#8c564b',
#           '#8c564b',
#           '#7f7f7f',
#           '#8c564b',
#           '#98df8a',
#           '#e377c2',
#           '#7f7f7f',
#           '#98df8a',
#           '#7f7f7f',
#           '#98df8a',
#           '#9467bd',
#           '#e377c2',
#           '#98df8a',
#           '#c7c7c7',
#           '#e377c2',
#           '#bcbd22',
#           '#7f7f7f',
#           '#ffbb78',
#           '#9467bd',
#           '#1f77b4',
#           '#c7c7c7',
#           '#2ca02c',
#           '#c7c7c7',
#           '#8c564b',
#           '#c7c7c7',
#           '#9edae5',
#           '#bcbd22',
#           '#8c564b',
#           '#8c564b',
#           '#9467bd',
#           '#aec7e8',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#e377c2',
#           '#bcbd22',
#           '#8c564b',
#           '#ff7f0e',
#           '#9edae5',
#           '#ffbb78',
#           '#ff7f0e',
#           '#9467bd',
#           '#8c564b',
#           '#98df8a',
#           '#1f77b4',
#           '#c7c7c7',
#           '#98df8a',
#           '#e377c2',
#           '#e377c2',
#           '#98df8a',
#           '#98df8a',
#           '#c7c7c7',
#           '#9467bd',
#           '#e377c2',
#           '#9edae5',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#c7c7c7',
#           '#e377c2',
#           '#c7c7c7',
#           '#98df8a',
#           '#17becf',
#           '#7f7f7f',
#           '#8c564b',
#           '#ffbb78',
#           '#e377c2',
#           '#bcbd22',
#           '#dbdb8d',
#           '#e377c2',
#           '#9467bd',
#           '#c7c7c7',
#           '#e377c2',
#           '#9467bd',
#           '#c49c94',
#           '#7f7f7f',
#           '#2ca02c',
#           '#9467bd',
#           '#7f7f7f',
#           '#8c564b',
#           '#7f7f7f',
#           '#9467bd',
#           '#7f7f7f',
#           '#1f77b4',
#           '#e377c2',
#           '#ffbb78',
#           '#c7c7c7',
#           '#e377c2',
#           '#9467bd',
#           '#c7c7c7',
#           '#98df8a',
#           '#1f77b4',
#           '#bcbd22',
#           '#e377c2',
#           '#ffbb78',
#           '#e377c2',
#           '#e377c2',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#9467bd',
#           '#e377c2',
#           '#1f77b4',
#           '#aec7e8',
#           '#1f77b4',
#           '#9467bd',
#           '#c7c7c7',
#           '#e377c2',
#           '#9467bd',
#           '#e377c2',
#           '#f7b6d2',
#           '#9467bd',
#           '#bcbd22',
#           '#9467bd',
#           '#f7b6d2',
#           '#e377c2',
#           '#9467bd',
#           '#9467bd',
#           '#f7b6d2',
#           '#1f77b4',
#           '#aec7e8',
#           '#e377c2',
#           '#e377c2',
#           '#98df8a',
#           '#7f7f7f',
#           '#9edae5',
#           '#7f7f7f',
#           '#9467bd',
#           '#bcbd22',
#           '#9467bd',
#           '#e377c2',
#           '#f7b6d2',
#           '#c7c7c7',
#           '#1f77b4',
#           '#c7c7c7',
#           '#8c564b',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#bcbd22',
#           '#f7b6d2',
#           '#e377c2',
#           '#98df8a',
#           '#8c564b',
#           '#e377c2',
#           '#7f7f7f',
#           '#e377c2',
#           '#bcbd22',
#           '#e377c2',
#           '#9467bd',
#           '#98df8a',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#9467bd',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#98df8a',
#           '#7f7f7f',
#           '#9467bd',
#           '#aec7e8',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#bcbd22',
#           '#ff7f0e',
#           '#f7b6d2',
#           '#c7c7c7',
#           '#98df8a',
#           '#e377c2',
#           '#7f7f7f',
#           '#bcbd22',
#           '#aec7e8',
#           '#f7b6d2',
#           '#e377c2',
#           '#e377c2',
#           '#2ca02c',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#7f7f7f',
#           '#8c564b',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#8c564b',
#           '#c7c7c7',
#           '#98df8a',
#           '#c7c7c7',
#           '#9467bd',
#           '#dbdb8d',
#           '#e377c2',
#           '#98df8a',
#           '#8c564b',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#bcbd22',
#           '#98df8a',
#           '#98df8a',
#           '#17becf',
#           '#2ca02c',
#           '#aec7e8',
#           '#e377c2',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#1f77b4',
#           '#ff7f0e',
#           '#f7b6d2',
#           '#9467bd',
#           '#9edae5',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#7f7f7f',
#           '#17becf',
#           '#7f7f7f',
#           '#17becf',
#           '#17becf',
#           '#9467bd',
#           '#e377c2',
#           '#c49c94',
#           '#1f77b4',
#           '#f7b6d2',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#bcbd22',
#           '#9467bd',
#           '#ffbb78',
#           '#8c564b',
#           '#bcbd22',
#           '#e377c2',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#98df8a',
#           '#1f77b4',
#           '#9467bd',
#           '#9467bd',
#           '#8c564b',
#           '#c7c7c7',
#           '#ffbb78',
#           '#e377c2',
#           '#8c564b',
#           '#e377c2',
#           '#c49c94',
#           '#1f77b4',
#           '#7f7f7f',
#           '#9467bd',
#           '#9467bd',
#           '#8c564b',
#           '#7f7f7f',
#           '#bcbd22',
#           '#c7c7c7',
#           '#ffbb78',
#           '#1f77b4',
#           '#f7b6d2',
#           '#e377c2',
#           '#e377c2',
#           '#e377c2',
#           '#17becf',
#           '#e377c2',
#           '#7f7f7f',
#           '#98df8a',
#           '#f7b6d2',
#           '#98df8a',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#17becf',
#           '#bcbd22',
#           '#c7c7c7',
#           '#98df8a',
#           '#98df8a',
#           '#f7b6d2',
#           '#8c564b',
#           '#98df8a',
#           '#9467bd',
#           '#e377c2',
#           '#98df8a',
#           '#c7c7c7',
#           '#9edae5',
#           '#7f7f7f',
#           '#9467bd',
#           '#9467bd',
#           '#e377c2',
#           '#98df8a',
#           '#c49c94',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#f7b6d2',
#           '#9467bd',
#           '#7f7f7f',
#           '#8c564b',
#           '#ff7f0e',
#           '#e377c2',
#           '#9467bd',
#           '#c7c7c7',
#           '#98df8a',
#           '#e377c2',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#1f77b4',
#           '#c7c7c7',
#           '#9467bd',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#e377c2',
#           '#8c564b',
#           '#c7c7c7',
#           '#9edae5',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#98df8a',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#f7b6d2',
#           '#9edae5',
#           '#17becf',
#           '#e377c2',
#           '#ffbb78',
#           '#2ca02c',
#           '#e377c2',
#           '#17becf',
#           '#9467bd',
#           '#ff9896',
#           '#c7c7c7',
#           '#e377c2',
#           '#8c564b',
#           '#17becf',
#           '#e377c2',
#           '#e377c2',
#           '#9467bd',
#           '#9467bd',
#           '#ff7f0e',
#           '#8c564b',
#           '#e377c2',
#           '#f7b6d2',
#           '#9467bd',
#           '#9467bd',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#aec7e8',
#           '#f7b6d2',
#           '#8c564b',
#           '#e377c2',
#           '#1f77b4',
#           '#98df8a',
#           '#8c564b',
#           '#e377c2',
#           '#9edae5',
#           '#98df8a',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#98df8a',
#           '#aec7e8',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#e377c2',
#           '#17becf',
#           '#17becf',
#           '#ffbb78',
#           '#1f77b4',
#           '#98df8a',
#           '#e377c2',
#           '#7f7f7f',
#           '#9467bd',
#           '#8c564b',
#           '#ff7f0e',
#           '#7f7f7f',
#           '#e377c2',
#           '#8c564b',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#e377c2',
#           '#c7c7c7',
#           '#ff7f0e',
#           '#9467bd',
#           '#7f7f7f',
#           '#9467bd',
#           '#8c564b',
#           '#7f7f7f',
#           '#bcbd22',
#           '#e377c2',
#           '#e377c2',
#           '#9467bd',
#           '#17becf',
#           '#9edae5',
#           '#e377c2',
#           '#bcbd22',
#           '#e377c2',
#           '#dbdb8d',
#           '#7f7f7f',
#           '#c49c94',
#           '#8c564b',
#           '#e377c2',
#           '#98df8a',
#           '#7f7f7f',
#           '#e377c2',
#           '#c7c7c7',
#           '#9edae5',
#           '#9467bd',
#           '#e377c2',
#           '#8c564b',
#           '#c7c7c7',
#           '#ffbb78',
#           '#9467bd',
#           '#bcbd22',
#           '#9467bd',
#           '#dbdb8d',
#           '#8c564b',
#           '#f7b6d2',
#           '#c7c7c7',
#           '#e377c2',
#           '#8c564b',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#bcbd22',
#           '#c7c7c7',
#           '#c49c94',
#           '#9edae5',
#           '#9467bd',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#f7b6d2',
#           '#e377c2',
#           '#9467bd',
#           '#e377c2',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#9edae5',
#           '#e377c2',
#           '#c5b0d5',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#98df8a',
#           '#7f7f7f',
#           '#9467bd',
#           '#c7c7c7',
#           '#d62728',
#           '#17becf',
#           '#9467bd',
#           '#7f7f7f',
#           '#8c564b',
#           '#bcbd22',
#           '#e377c2',
#           '#c7c7c7',
#           '#9467bd',
#           '#ffbb78',
#           '#e377c2',
#           '#9467bd',
#           '#e377c2',
#           '#c5b0d5',
#           '#c7c7c7',
#           '#9467bd',
#           '#1f77b4',
#           '#98df8a',
#           '#c7c7c7',
#           '#ffbb78',
#           '#c7c7c7',
#           '#98df8a',
#           '#e377c2',
#           '#dbdb8d',
#           '#98df8a',
#           '#9467bd',
#           '#c7c7c7',
#           '#c49c94',
#           '#c7c7c7',
#           '#f7b6d2',
#           '#f7b6d2',
#           '#bcbd22',
#           '#bcbd22',
#           '#f7b6d2',
#           '#9467bd',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#c49c94',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#e377c2',
#           '#98df8a',
#           '#e377c2',
#           '#9467bd',
#           '#7f7f7f',
#           '#e377c2',
#           '#c7c7c7',
#           '#9edae5',
#           '#e377c2',
#           '#7f7f7f',
#           '#e377c2',
#           '#f7b6d2',
#           '#9467bd',
#           '#9467bd',
#           '#bcbd22',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#9467bd',
#           '#f7b6d2',
#           '#98df8a',
#           '#17becf',
#           '#e377c2',
#           '#9467bd',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#98df8a',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#9467bd',
#           '#ffbb78',
#           '#c49c94',
#           '#f7b6d2',
#           '#98df8a',
#           '#7f7f7f',
#           '#9467bd',
#           '#7f7f7f',
#           '#9467bd',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#9467bd',
#           '#e377c2',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#1f77b4',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#8c564b',
#           '#9467bd',
#           '#e377c2',
#           '#ffbb78',
#           '#c7c7c7',
#           '#17becf',
#           '#9467bd',
#           '#8c564b',
#           '#ff9896',
#           '#c7c7c7',
#           '#9467bd',
#           '#8c564b',
#           '#7f7f7f',
#           '#ffbb78',
#           '#8c564b',
#           '#c7c7c7',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#9edae5',
#           '#9467bd',
#           '#9edae5',
#           '#17becf',
#           '#e377c2',
#           '#ff7f0e',
#           '#f7b6d2',
#           '#f7b6d2',
#           '#9467bd',
#           '#17becf',
#           '#dbdb8d',
#           '#e377c2',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#e377c2',
#           '#7f7f7f',
#           '#9edae5',
#           '#c7c7c7',
#           '#c49c94',
#           '#f7b6d2',
#           '#c7c7c7',
#           '#17becf',
#           '#aec7e8',
#           '#e377c2',
#           '#c49c94',
#           '#8c564b',
#           '#9467bd',
#           '#1f77b4',
#           '#7f7f7f',
#           '#dbdb8d',
#           '#9467bd',
#           '#ffbb78',
#           '#e377c2',
#           '#ff7f0e',
#           '#c7c7c7',
#           '#98df8a',
#           '#9467bd',
#           '#9467bd',
#           '#ff7f0e',
#           '#ffbb78',
#           '#7f7f7f',
#           '#ffbb78',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#bcbd22',
#           '#17becf',
#           '#7f7f7f',
#           '#e377c2',
#           '#9467bd',
#           '#9467bd',
#           '#f7b6d2',
#           '#9467bd',
#           '#c7c7c7',
#           '#9467bd',
#           '#9467bd',
#           '#1f77b4',
#           '#c7c7c7',
#           '#e377c2',
#           '#9467bd',
#           '#7f7f7f',
#           '#17becf',
#           '#9467bd',
#           '#c7c7c7',
#           '#9467bd',
#           '#7f7f7f',
#           '#2ca02c',
#           '#c7c7c7',
#           '#ff7f0e',
#           '#9467bd',
#           '#9467bd',
#           '#e377c2',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#9467bd',
#           '#7f7f7f',
#           '#8c564b',
#           '#9467bd',
#           '#c7c7c7',
#           '#9467bd',
#           '#ff7f0e',
#           '#c7c7c7',
#           '#9467bd',
#           '#bcbd22',
#           '#17becf',
#           '#f7b6d2',
#           '#e377c2',
#           '#f7b6d2',
#           '#9467bd',
#           '#c7c7c7',
#           '#9edae5',
#           '#e377c2',
#           '#f7b6d2',
#           '#e377c2',
#           '#bcbd22',
#           '#7f7f7f',
#           '#9467bd',
#           '#e377c2',
#           '#9467bd',
#           '#c7c7c7',
#           '#bcbd22',
#           '#c7c7c7',
#           '#9467bd',
#           '#e377c2',
#           '#9467bd',
#           '#9467bd',
#           '#f7b6d2',
#           '#9467bd',
#           '#c7c7c7',
#           '#9edae5',
#           '#e377c2',
#           '#7f7f7f',
#           '#98df8a',
#           '#98df8a',
#           '#e377c2',
#           '#8c564b',
#           '#8c564b',
#           '#9467bd',
#           '#ff7f0e',
#           '#dbdb8d',
#           '#9467bd',
#           '#9467bd',
#           '#9467bd',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#9467bd',
#           '#8c564b',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#8c564b',
#           '#e377c2',
#           '#17becf',
#           '#17becf',
#           '#98df8a',
#           '#8c564b',
#           '#aec7e8',
#           '#f7b6d2',
#           '#ffbb78',
#           '#2ca02c',
#           '#2ca02c',
#           '#c7c7c7',
#           '#8c564b',
#           '#f7b6d2',
#           '#17becf',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#98df8a',
#           ...],
#          'fill_color': ['#7f7f7f',
#           '#9467bd',
#           '#1f77b4',
#           '#17becf',
#           '#9467bd',
#           '#8c564b',
#           '#c49c94',
#           '#f7b6d2',
#           '#8c564b',
#           '#e377c2',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#bcbd22',
#           '#98df8a',
#           '#9edae5',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#e377c2',
#           '#8c564b',
#           '#7f7f7f',
#           '#9467bd',
#           '#8c564b',
#           '#98df8a',
#           '#9467bd',
#           '#bcbd22',
#           '#7f7f7f',
#           '#8c564b',
#           '#c49c94',
#           '#17becf',
#           '#8c564b',
#           '#98df8a',
#           '#7f7f7f',
#           '#e377c2',
#           '#17becf',
#           '#bcbd22',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#9467bd',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#7f7f7f',
#           '#9467bd',
#           '#9467bd',
#           '#17becf',
#           '#17becf',
#           '#7f7f7f',
#           '#ffbb78',
#           '#9467bd',
#           '#bcbd22',
#           '#9467bd',
#           '#9467bd',
#           '#7f7f7f',
#           '#8c564b',
#           '#ffbb78',
#           '#7f7f7f',
#           '#e377c2',
#           '#f7b6d2',
#           '#9467bd',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#e377c2',
#           '#7f7f7f',
#           '#8c564b',
#           '#e377c2',
#           '#7f7f7f',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#98df8a',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#f7b6d2',
#           '#bcbd22',
#           '#e377c2',
#           '#c7c7c7',
#           '#9467bd',
#           '#17becf',
#           '#98df8a',
#           '#2ca02c',
#           '#ffbb78',
#           '#7f7f7f',
#           '#d62728',
#           '#98df8a',
#           '#c49c94',
#           '#7f7f7f',
#           '#98df8a',
#           '#e377c2',
#           '#f7b6d2',
#           '#f7b6d2',
#           '#e377c2',
#           '#f7b6d2',
#           '#8c564b',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#e377c2',
#           '#f7b6d2',
#           '#9467bd',
#           '#e377c2',
#           '#ffbb78',
#           '#9467bd',
#           '#9467bd',
#           '#9467bd',
#           '#f7b6d2',
#           '#f7b6d2',
#           '#e377c2',
#           '#ff7f0e',
#           '#9467bd',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#9467bd',
#           '#e377c2',
#           '#9edae5',
#           '#e377c2',
#           '#9edae5',
#           '#e377c2',
#           '#e377c2',
#           '#9467bd',
#           '#9467bd',
#           '#c7c7c7',
#           '#9467bd',
#           '#98df8a',
#           '#9467bd',
#           '#ff7f0e',
#           '#98df8a',
#           '#9467bd',
#           '#1f77b4',
#           '#dbdb8d',
#           '#ff7f0e',
#           '#c7c7c7',
#           '#9edae5',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#bcbd22',
#           '#7f7f7f',
#           '#8c564b',
#           '#9467bd',
#           '#dbdb8d',
#           '#f7b6d2',
#           '#9467bd',
#           '#f7b6d2',
#           '#8c564b',
#           '#e377c2',
#           '#e377c2',
#           '#98df8a',
#           '#e377c2',
#           '#f7b6d2',
#           '#8c564b',
#           '#7f7f7f',
#           '#e377c2',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#98df8a',
#           '#9467bd',
#           '#9467bd',
#           '#8c564b',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#17becf',
#           '#8c564b',
#           '#e377c2',
#           '#e377c2',
#           '#e377c2',
#           '#17becf',
#           '#c7c7c7',
#           '#ffbb78',
#           '#7f7f7f',
#           '#17becf',
#           '#9467bd',
#           '#c7c7c7',
#           '#9467bd',
#           '#9467bd',
#           '#e377c2',
#           '#1f77b4',
#           '#98df8a',
#           '#c7c7c7',
#           '#ffbb78',
#           '#9467bd',
#           '#f7b6d2',
#           '#e377c2',
#           '#98df8a',
#           '#8c564b',
#           '#9467bd',
#           '#c7c7c7',
#           '#9467bd',
#           '#1f77b4',
#           '#bcbd22',
#           '#9467bd',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#17becf',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#17becf',
#           '#e377c2',
#           '#9467bd',
#           '#8c564b',
#           '#17becf',
#           '#e377c2',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#8c564b',
#           '#e377c2',
#           '#ffbb78',
#           '#8c564b',
#           '#17becf',
#           '#8c564b',
#           '#8c564b',
#           '#8c564b',
#           '#dbdb8d',
#           '#98df8a',
#           '#9467bd',
#           '#7f7f7f',
#           '#e377c2',
#           '#9467bd',
#           '#17becf',
#           '#98df8a',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#17becf',
#           '#e377c2',
#           '#9467bd',
#           '#17becf',
#           '#e377c2',
#           '#ff7f0e',
#           '#17becf',
#           '#98df8a',
#           '#17becf',
#           '#e377c2',
#           '#7f7f7f',
#           '#17becf',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#e377c2',
#           '#f7b6d2',
#           '#c7c7c7',
#           '#bcbd22',
#           '#98df8a',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#e377c2',
#           '#1f77b4',
#           '#c7c7c7',
#           '#9467bd',
#           '#17becf',
#           '#9467bd',
#           '#aec7e8',
#           '#c7c7c7',
#           '#98df8a',
#           '#e377c2',
#           '#c5b0d5',
#           '#7f7f7f',
#           '#9467bd',
#           '#2ca02c',
#           '#bcbd22',
#           '#e377c2',
#           '#bcbd22',
#           '#9467bd',
#           '#2ca02c',
#           '#f7b6d2',
#           '#9467bd',
#           '#bcbd22',
#           '#7f7f7f',
#           '#9467bd',
#           '#7f7f7f',
#           '#98df8a',
#           '#9467bd',
#           '#c49c94',
#           '#f7b6d2',
#           '#e377c2',
#           '#17becf',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#9467bd',
#           '#98df8a',
#           '#8c564b',
#           '#bcbd22',
#           '#7f7f7f',
#           '#e377c2',
#           '#e377c2',
#           '#9467bd',
#           '#ff7f0e',
#           '#f7b6d2',
#           '#9467bd',
#           '#aec7e8',
#           '#7f7f7f',
#           '#9467bd',
#           '#2ca02c',
#           '#8c564b',
#           '#f7b6d2',
#           '#e377c2',
#           '#9edae5',
#           '#7f7f7f',
#           '#8c564b',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#e377c2',
#           '#8c564b',
#           '#8c564b',
#           '#e377c2',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#8c564b',
#           '#8c564b',
#           '#7f7f7f',
#           '#8c564b',
#           '#98df8a',
#           '#e377c2',
#           '#7f7f7f',
#           '#98df8a',
#           '#7f7f7f',
#           '#98df8a',
#           '#9467bd',
#           '#e377c2',
#           '#98df8a',
#           '#c7c7c7',
#           '#e377c2',
#           '#bcbd22',
#           '#7f7f7f',
#           '#ffbb78',
#           '#9467bd',
#           '#1f77b4',
#           '#c7c7c7',
#           '#2ca02c',
#           '#c7c7c7',
#           '#8c564b',
#           '#c7c7c7',
#           '#9edae5',
#           '#bcbd22',
#           '#8c564b',
#           '#8c564b',
#           '#9467bd',
#           '#aec7e8',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#e377c2',
#           '#bcbd22',
#           '#8c564b',
#           '#ff7f0e',
#           '#9edae5',
#           '#ffbb78',
#           '#ff7f0e',
#           '#9467bd',
#           '#8c564b',
#           '#98df8a',
#           '#1f77b4',
#           '#c7c7c7',
#           '#98df8a',
#           '#e377c2',
#           '#e377c2',
#           '#98df8a',
#           '#98df8a',
#           '#c7c7c7',
#           '#9467bd',
#           '#e377c2',
#           '#9edae5',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#c7c7c7',
#           '#e377c2',
#           '#c7c7c7',
#           '#98df8a',
#           '#17becf',
#           '#7f7f7f',
#           '#8c564b',
#           '#ffbb78',
#           '#e377c2',
#           '#bcbd22',
#           '#dbdb8d',
#           '#e377c2',
#           '#9467bd',
#           '#c7c7c7',
#           '#e377c2',
#           '#9467bd',
#           '#c49c94',
#           '#7f7f7f',
#           '#2ca02c',
#           '#9467bd',
#           '#7f7f7f',
#           '#8c564b',
#           '#7f7f7f',
#           '#9467bd',
#           '#7f7f7f',
#           '#1f77b4',
#           '#e377c2',
#           '#ffbb78',
#           '#c7c7c7',
#           '#e377c2',
#           '#9467bd',
#           '#c7c7c7',
#           '#98df8a',
#           '#1f77b4',
#           '#bcbd22',
#           '#e377c2',
#           '#ffbb78',
#           '#e377c2',
#           '#e377c2',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#9467bd',
#           '#e377c2',
#           '#1f77b4',
#           '#aec7e8',
#           '#1f77b4',
#           '#9467bd',
#           '#c7c7c7',
#           '#e377c2',
#           '#9467bd',
#           '#e377c2',
#           '#f7b6d2',
#           '#9467bd',
#           '#bcbd22',
#           '#9467bd',
#           '#f7b6d2',
#           '#e377c2',
#           '#9467bd',
#           '#9467bd',
#           '#f7b6d2',
#           '#1f77b4',
#           '#aec7e8',
#           '#e377c2',
#           '#e377c2',
#           '#98df8a',
#           '#7f7f7f',
#           '#9edae5',
#           '#7f7f7f',
#           '#9467bd',
#           '#bcbd22',
#           '#9467bd',
#           '#e377c2',
#           '#f7b6d2',
#           '#c7c7c7',
#           '#1f77b4',
#           '#c7c7c7',
#           '#8c564b',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#bcbd22',
#           '#f7b6d2',
#           '#e377c2',
#           '#98df8a',
#           '#8c564b',
#           '#e377c2',
#           '#7f7f7f',
#           '#e377c2',
#           '#bcbd22',
#           '#e377c2',
#           '#9467bd',
#           '#98df8a',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#9467bd',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#98df8a',
#           '#7f7f7f',
#           '#9467bd',
#           '#aec7e8',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#bcbd22',
#           '#ff7f0e',
#           '#f7b6d2',
#           '#c7c7c7',
#           '#98df8a',
#           '#e377c2',
#           '#7f7f7f',
#           '#bcbd22',
#           '#aec7e8',
#           '#f7b6d2',
#           '#e377c2',
#           '#e377c2',
#           '#2ca02c',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#7f7f7f',
#           '#8c564b',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#8c564b',
#           '#c7c7c7',
#           '#98df8a',
#           '#c7c7c7',
#           '#9467bd',
#           '#dbdb8d',
#           '#e377c2',
#           '#98df8a',
#           '#8c564b',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#bcbd22',
#           '#98df8a',
#           '#98df8a',
#           '#17becf',
#           '#2ca02c',
#           '#aec7e8',
#           '#e377c2',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#1f77b4',
#           '#ff7f0e',
#           '#f7b6d2',
#           '#9467bd',
#           '#9edae5',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#7f7f7f',
#           '#17becf',
#           '#7f7f7f',
#           '#17becf',
#           '#17becf',
#           '#9467bd',
#           '#e377c2',
#           '#c49c94',
#           '#1f77b4',
#           '#f7b6d2',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#bcbd22',
#           '#9467bd',
#           '#ffbb78',
#           '#8c564b',
#           '#bcbd22',
#           '#e377c2',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#98df8a',
#           '#1f77b4',
#           '#9467bd',
#           '#9467bd',
#           '#8c564b',
#           '#c7c7c7',
#           '#ffbb78',
#           '#e377c2',
#           '#8c564b',
#           '#e377c2',
#           '#c49c94',
#           '#1f77b4',
#           '#7f7f7f',
#           '#9467bd',
#           '#9467bd',
#           '#8c564b',
#           '#7f7f7f',
#           '#bcbd22',
#           '#c7c7c7',
#           '#ffbb78',
#           '#1f77b4',
#           '#f7b6d2',
#           '#e377c2',
#           '#e377c2',
#           '#e377c2',
#           '#17becf',
#           '#e377c2',
#           '#7f7f7f',
#           '#98df8a',
#           '#f7b6d2',
#           '#98df8a',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#17becf',
#           '#bcbd22',
#           '#c7c7c7',
#           '#98df8a',
#           '#98df8a',
#           '#f7b6d2',
#           '#8c564b',
#           '#98df8a',
#           '#9467bd',
#           '#e377c2',
#           '#98df8a',
#           '#c7c7c7',
#           '#9edae5',
#           '#7f7f7f',
#           '#9467bd',
#           '#9467bd',
#           '#e377c2',
#           '#98df8a',
#           '#c49c94',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#f7b6d2',
#           '#9467bd',
#           '#7f7f7f',
#           '#8c564b',
#           '#ff7f0e',
#           '#e377c2',
#           '#9467bd',
#           '#c7c7c7',
#           '#98df8a',
#           '#e377c2',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#1f77b4',
#           '#c7c7c7',
#           '#9467bd',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#e377c2',
#           '#8c564b',
#           '#c7c7c7',
#           '#9edae5',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#98df8a',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#f7b6d2',
#           '#9edae5',
#           '#17becf',
#           '#e377c2',
#           '#ffbb78',
#           '#2ca02c',
#           '#e377c2',
#           '#17becf',
#           '#9467bd',
#           '#ff9896',
#           '#c7c7c7',
#           '#e377c2',
#           '#8c564b',
#           '#17becf',
#           '#e377c2',
#           '#e377c2',
#           '#9467bd',
#           '#9467bd',
#           '#ff7f0e',
#           '#8c564b',
#           '#e377c2',
#           '#f7b6d2',
#           '#9467bd',
#           '#9467bd',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#aec7e8',
#           '#f7b6d2',
#           '#8c564b',
#           '#e377c2',
#           '#1f77b4',
#           '#98df8a',
#           '#8c564b',
#           '#e377c2',
#           '#9edae5',
#           '#98df8a',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#98df8a',
#           '#aec7e8',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#e377c2',
#           '#17becf',
#           '#17becf',
#           '#ffbb78',
#           '#1f77b4',
#           '#98df8a',
#           '#e377c2',
#           '#7f7f7f',
#           '#9467bd',
#           '#8c564b',
#           '#ff7f0e',
#           '#7f7f7f',
#           '#e377c2',
#           '#8c564b',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#e377c2',
#           '#c7c7c7',
#           '#ff7f0e',
#           '#9467bd',
#           '#7f7f7f',
#           '#9467bd',
#           '#8c564b',
#           '#7f7f7f',
#           '#bcbd22',
#           '#e377c2',
#           '#e377c2',
#           '#9467bd',
#           '#17becf',
#           '#9edae5',
#           '#e377c2',
#           '#bcbd22',
#           '#e377c2',
#           '#dbdb8d',
#           '#7f7f7f',
#           '#c49c94',
#           '#8c564b',
#           '#e377c2',
#           '#98df8a',
#           '#7f7f7f',
#           '#e377c2',
#           '#c7c7c7',
#           '#9edae5',
#           '#9467bd',
#           '#e377c2',
#           '#8c564b',
#           '#c7c7c7',
#           '#ffbb78',
#           '#9467bd',
#           '#bcbd22',
#           '#9467bd',
#           '#dbdb8d',
#           '#8c564b',
#           '#f7b6d2',
#           '#c7c7c7',
#           '#e377c2',
#           '#8c564b',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#bcbd22',
#           '#c7c7c7',
#           '#c49c94',
#           '#9edae5',
#           '#9467bd',
#           '#9467bd',
#           '#e377c2',
#           '#e377c2',
#           '#f7b6d2',
#           '#e377c2',
#           '#9467bd',
#           '#e377c2',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#9edae5',
#           '#e377c2',
#           '#c5b0d5',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#98df8a',
#           '#7f7f7f',
#           '#9467bd',
#           '#c7c7c7',
#           '#d62728',
#           '#17becf',
#           '#9467bd',
#           '#7f7f7f',
#           '#8c564b',
#           '#bcbd22',
#           '#e377c2',
#           '#c7c7c7',
#           '#9467bd',
#           '#ffbb78',
#           '#e377c2',
#           '#9467bd',
#           '#e377c2',
#           '#c5b0d5',
#           '#c7c7c7',
#           '#9467bd',
#           '#1f77b4',
#           '#98df8a',
#           '#c7c7c7',
#           '#ffbb78',
#           '#c7c7c7',
#           '#98df8a',
#           '#e377c2',
#           '#dbdb8d',
#           '#98df8a',
#           '#9467bd',
#           '#c7c7c7',
#           '#c49c94',
#           '#c7c7c7',
#           '#f7b6d2',
#           '#f7b6d2',
#           '#bcbd22',
#           '#bcbd22',
#           '#f7b6d2',
#           '#9467bd',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#c49c94',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#e377c2',
#           '#98df8a',
#           '#e377c2',
#           '#9467bd',
#           '#7f7f7f',
#           '#e377c2',
#           '#c7c7c7',
#           '#9edae5',
#           '#e377c2',
#           '#7f7f7f',
#           '#e377c2',
#           '#f7b6d2',
#           '#9467bd',
#           '#9467bd',
#           '#bcbd22',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#9467bd',
#           '#f7b6d2',
#           '#98df8a',
#           '#17becf',
#           '#e377c2',
#           '#9467bd',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#98df8a',
#           '#7f7f7f',
#           '#7f7f7f',
#           '#9467bd',
#           '#ffbb78',
#           '#c49c94',
#           '#f7b6d2',
#           '#98df8a',
#           '#7f7f7f',
#           '#9467bd',
#           '#7f7f7f',
#           '#9467bd',
#           '#7f7f7f',
#           '#ff7f0e',
#           '#9467bd',
#           '#e377c2',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#1f77b4',
#           '#7f7f7f',
#           '#f7b6d2',
#           '#8c564b',
#           '#9467bd',
#           '#e377c2',
#           '#ffbb78',
#           '#c7c7c7',
#           '#17becf',
#           '#9467bd',
#           '#8c564b',
#           '#ff9896',
#           '#c7c7c7',
#           '#9467bd',
#           '#8c564b',
#           '#7f7f7f',
#           '#ffbb78',
#           '#8c564b',
#           '#c7c7c7',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#9edae5',
#           '#9467bd',
#           '#9edae5',
#           '#17becf',
#           '#e377c2',
#           '#ff7f0e',
#           '#f7b6d2',
#           '#f7b6d2',
#           '#9467bd',
#           '#17becf',
#           '#dbdb8d',
#           '#e377c2',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#e377c2',
#           '#7f7f7f',
#           '#9edae5',
#           '#c7c7c7',
#           '#c49c94',
#           '#f7b6d2',
#           '#c7c7c7',
#           '#17becf',
#           '#aec7e8',
#           '#e377c2',
#           '#c49c94',
#           '#8c564b',
#           '#9467bd',
#           '#1f77b4',
#           '#7f7f7f',
#           '#dbdb8d',
#           '#9467bd',
#           '#ffbb78',
#           '#e377c2',
#           '#ff7f0e',
#           '#c7c7c7',
#           '#98df8a',
#           '#9467bd',
#           '#9467bd',
#           '#ff7f0e',
#           '#ffbb78',
#           '#7f7f7f',
#           '#ffbb78',
#           '#f7b6d2',
#           '#7f7f7f',
#           '#bcbd22',
#           '#17becf',
#           '#7f7f7f',
#           '#e377c2',
#           '#9467bd',
#           '#9467bd',
#           '#f7b6d2',
#           '#9467bd',
#           '#c7c7c7',
#           '#9467bd',
#           '#9467bd',
#           '#1f77b4',
#           '#c7c7c7',
#           '#e377c2',
#           '#9467bd',
#           '#7f7f7f',
#           '#17becf',
#           '#9467bd',
#           '#c7c7c7',
#           '#9467bd',
#           '#7f7f7f',
#           '#2ca02c',
#           '#c7c7c7',
#           '#ff7f0e',
#           '#9467bd',
#           '#9467bd',
#           '#e377c2',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#9467bd',
#           '#7f7f7f',
#           '#8c564b',
#           '#9467bd',
#           '#c7c7c7',
#           '#9467bd',
#           '#ff7f0e',
#           '#c7c7c7',
#           '#9467bd',
#           '#bcbd22',
#           '#17becf',
#           '#f7b6d2',
#           '#e377c2',
#           '#f7b6d2',
#           '#9467bd',
#           '#c7c7c7',
#           '#9edae5',
#           '#e377c2',
#           '#f7b6d2',
#           '#e377c2',
#           '#bcbd22',
#           '#7f7f7f',
#           '#9467bd',
#           '#e377c2',
#           '#9467bd',
#           '#c7c7c7',
#           '#bcbd22',
#           '#c7c7c7',
#           '#9467bd',
#           '#e377c2',
#           '#9467bd',
#           '#9467bd',
#           '#f7b6d2',
#           '#9467bd',
#           '#c7c7c7',
#           '#9edae5',
#           '#e377c2',
#           '#7f7f7f',
#           '#98df8a',
#           '#98df8a',
#           '#e377c2',
#           '#8c564b',
#           '#8c564b',
#           '#9467bd',
#           '#ff7f0e',
#           '#dbdb8d',
#           '#9467bd',
#           '#9467bd',
#           '#9467bd',
#           '#7f7f7f',
#           '#c7c7c7',
#           '#9467bd',
#           '#8c564b',
#           '#c7c7c7',
#           '#c7c7c7',
#           '#8c564b',
#           '#e377c2',
#           '#17becf',
#           '#17becf',
#           '#98df8a',
#           '#8c564b',
#           '#aec7e8',
#           '#f7b6d2',
#           '#ffbb78',
#           '#2ca02c',
#           '#2ca02c',
#           '#c7c7c7',
#           '#8c564b',
#           '#f7b6d2',
#           '#17becf',
#           '#c7c7c7',
#           '#7f7f7f',
#           '#98df8a',
#           ...]},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         selected=bokeh.models.selections.Selection(
#             id='687d8713-2189-4f9e-9eab-12940e2da563',
#             indices=[],
#             js_event_callbacks={},
#             js_property_callbacks={},
#             line_indices=[],
#             multiline_indices={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         selection_policy=bokeh.models.selections.UnionRenderers(
#             id='e87696ba-02cd-46bb-ad2e-50b7d292fbbe',
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     glyph=bokeh.models.markers.Circle(
#         id='920c9000-2818-45f9-9aa8-b6816f3d0ed4',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 1.0},
#         fill_color={'field': 'fill_color'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 1.0},
#         line_cap='butt',
#         line_color={'field': 'line_color'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     hover_glyph=None,
#     js_event_callbacks={},
#     js_property_callbacks={},
#     level='glyph',
#     muted=False,
#     muted_glyph=None,
#     name=None,
#     nonselection_glyph=bokeh.models.markers.Circle(
#         id='d69e7ba1-1f3d-4565-a0f6-a710ecffed47',
#         angle={'value': 0.0, 'units': 'rad'},
#         fill_alpha={'value': 0.1},
#         fill_color={'value': '#1f77b4'},
#         js_event_callbacks={},
#         js_property_callbacks={},
#         line_alpha={'value': 0.1},
#         line_cap='butt',
#         line_color={'value': '#1f77b4'},
#         line_dash=[],
#         line_dash_offset=0,
#         line_join='bevel',
#         line_width={'value': 1},
#         name=None,
#         radius=None,
#         radius_dimension='x',
#         size={'value': 4, 'units': 'screen'},
#         subscribed_events=[],
#         tags=[],
#         x={'field': 'x'},
#         y={'field': 'y'}),
#     selection_glyph=None,
#     subscribed_events=[],
#     tags=[],
#     view=bokeh.models.sources.CDSView(
#         id='d4765c0c-9dee-49c9-ace3-26eadf4ff9fe',
#         filters=[],
#         js_event_callbacks={},
#         js_property_callbacks={},
#         name=None,
#         source=bokeh.models.sources.ColumnDataSource(
#             id='c38d1f07-8111-4d7d-9c0b-68f4669e027f',
#             callback=None,
#             data={'y': {'__ndarray__': '...',
#               'shape': (9129,),
#               'dtype': 'float32'},
#              'x': {'__ndarray__': '...',
#               'shape': (9129,),
#               'dtype': 'float32'},
#              'line_color': ['#7f7f7f',
#               '#9467bd',
#               '#1f77b4',
#               '#17becf',
#               '#9467bd',
#               '#8c564b',
#               '#c49c94',
#               '#f7b6d2',
#               '#8c564b',
#               '#e377c2',
#               '#c7c7c7',
#               '#7f7f7f',
#               '#c7c7c7',
#               '#7f7f7f',
#               '#bcbd22',
#               '#98df8a',
#               '#9edae5',
#               '#c7c7c7',
#               '#c7c7c7',
#               '#e377c2',
#               '#8c564b',
#               '#7f7f7f',
#               '#9467bd',
#               '#8c564b',
#               '#98df8a',
#               '#9467bd',
#               '#bcbd22',
#               '#7f7f7f',
#               '#8c564b',
#               '#c49c94',
#               '#17becf',
#               '#8c564b',
#               '#98df8a',
#               '#7f7f7f',
#               '#e377c2',
#               '#17becf',
#               '#bcbd22',
#               '#7f7f7f',
#               '#7f7f7f',
#               '#9467bd',
#               '#7f7f7f',
#               '#ff7f0e',
#               '#7f7f7f',
#               '#9467bd',
#               '#9467bd',
#               '#17becf',
#               '#17becf',
#               '#7f7f7f',
#               '#ffbb78',
#               '#9467bd',
#               '#bcbd22',
#               '#9467bd',
#               '#9467bd',
#               '#7f7f7f',
#               '#8c564b',
#               '#ffbb78',
#               '#7f7f7f',
#               '#e377c2',
#               '#f7b6d2',
#               '#9467bd',
#               '#9467bd',
#               '#e377c2',
#               '#e377c2',
#               '#e377c2',
#               '#7f7f7f',
#               '#8c564b',
#               '#e377c2',
#               '#7f7f7f',
#               '#9467bd',
#               '#e377c2',
#               '#e377c2',
#               '#98df8a',
#               '#7f7f7f',
#               '#f7b6d2',
#               '#f7b6d2',
#               '#bcbd22',
#               '#e377c2',
#               '#c7c7c7',
#               '#9467bd',
#               '#17becf',
#               '#98df8a',
#               '#2ca02c',
#               '#ffbb78',
#               '#7f7f7f',
#               '#d62728',
#               '#98df8a',
#               '#c49c94',
#               '#7f7f7f',
#               '#98df8a',
#               '#e377c2',
#               '#f7b6d2',
#               '#f7b6d2',
#               '#e377c2',
#               '#f7b6d2',
#               '#8c564b',
#               '#c7c7c7',
#               '#7f7f7f',
#               '#e377c2',
#               '#f7b6d2',
#               '#9467bd',
#               '#e377c2',
#               '#ffbb78',
# ...
#               '#bcbd22',
#               '#e377c2',
#               '#ffbb78',
#               '#e377c2',
#               '#e377c2',
#               '#7f7f7f',
#               '#7f7f7f',
#               '#9467bd',
#               '#e377c2',
#               '#1f77b4',
#               '#aec7e8',
#               '#1f77b4',
#               '#9467bd',
#               '#c7c7c7',
#               '#e377c2',
#               '#9467bd',
#               '#e377c2',
#               '#f7b6d2',
#               '#9467bd',
#               '#bcbd22',
#               '#9467bd',
#               '#f7b6d2',
#               '#e377c2',
#               '#9467bd',
#               '#9467bd',
#               '#f7b6d2',
#               '#1f77b4',
#               '#aec7e8',
#               '#e377c2',
#               '#e377c2',
#               '#98df8a',
#               '#7f7f7f',
#               '#9edae5',
#               '#7f7f7f',
#               '#9467bd',
#               '#bcbd22',
#               '#9467bd',
#               '#e377c2',
#               '#f7b6d2',
#               '#c7c7c7',
#               '#1f77b4',
#               '#c7c7c7',
#               '#8c564b',
#               '#f7b6d2',
#               '#7f7f7f',
#               '#7f7f7f',
#               '#bcbd22',
#               '#f7b6d2',
#               '#e377c2',
#               '#98df8a',
#               '#8c564b',
#               '#e377c2',
#               '#7f7f7f',
#               '#e377c2',
#               '#bcbd22',
#               '#e377c2',
#               '#9467bd',
#               '#98df8a',
#               '#7f7f7f',
#               '#7f7f7f',
#               '#9467bd',
#               '#7f7f7f',
#               '#7f7f7f',
#               '#98df8a',
#               '#7f7f7f',
#               '#9467bd',
#               '#aec7e8',
#               '#c7c7c7',
#               '#c7c7c7',
#               '#7f7f7f',
#               '#f7b6d2',
#               '#bcbd22',
#               '#ff7f0e',
#               '#f7b6d2',
#               '#c7c7c7',
#               '#98df8a',
#               '#e377c2',
#               '#7f7f7f',
#               '#bcbd22',
#               '#aec7e8',
#               '#f7b6d2',
#               '#e377c2',
#               '#e377c2',
#               '#2ca02c',
#               '#9467bd',
#               '#e377c2',
#               '#e377c2',
#               '#7f7f7f',
#               '#8c564b',
#               '#7f7f7f',
#               '#c7c7c7',
#               '#8c564b',
#               '#c7c7c7',
#               '#98df8a',
#               '#c7c7c7',
#               '#9467bd',
#               '#dbdb8d',
#               '#e377c2',
#               '#98df8a',
#               '#8c564b',
#               '#7f7f7f',
#               '#7f7f7f',
#               '#ff7f0e',
#               '#bcbd22',
#               '#98df8a',
#               '#98df8a',
#               '#17becf',
#               '#2ca02c',
#               '#aec7e8',
#               '#e377c2',
#               '#7f7f7f',
#               '#c7c7c7',
#               '#1f77b4',
#               '#ff7f0e',
#               '#f7b6d2',
#               '#9467bd',
#               '#9edae5',
#               '#9467bd',
#               '#e377c2',
#               '#e377c2',
#               '#7f7f7f',
#               '#17becf',
#               '#7f7f7f',
#               '#17becf',
#               '#17becf',
#               '#9467bd',
#               '#e377c2',
#               '#c49c94',
#               '#1f77b4',
#               '#f7b6d2',
#               '#f7b6d2',
#               '#7f7f7f',
#               '#c7c7c7',
#               '#bcbd22',
#               '#9467bd',
#               '#ffbb78',
#               '#8c564b',
#               '#bcbd22',
#               '#e377c2',
#               '#f7b6d2',
#               '#7f7f7f',
#               '#98df8a',
#               '#1f77b4',
#               '#9467bd',
#               '#9467bd',
#               '#8c564b',
#               '#c7c7c7',
#               '#ffbb78',
#               '#e377c2',
#               '#8c564b',
#               '#e377c2',
#               '#c49c94',
#               '#1f77b4',
#               '#7f7f7f',
#               '#9467bd',
#               '#9467bd',
#               '#8c564b',
#               '#7f7f7f',
#               '#bcbd22',
#               '#c7c7c7',
#               '#ffbb78',
#               '#1f77b4',
#               '#f7b6d2',
#               '#e377c2',
#               '#e377c2',
#               '#e377c2',
#               '#17becf',
#               '#e377c2',
#               '#7f7f7f',
#               '#98df8a',
#               '#f7b6d2',
#               '#98df8a',
#               '#7f7f7f',
#               '#f7b6d2',
#               '#17becf',
#               '#bcbd22',
#               '#c7c7c7',
#               '#98df8a',
#               '#98df8a',
#               '#f7b6d2',
#               '#8c564b',
#               '#98df8a',
#               '#9467bd',
#               '#e377c2',
#               '#98df8a',
#               '#c7c7c7',
#               '#9edae5',
#               '#7f7f7f',
#               '#9467bd',
#               '#9467bd',
#               '#e377c2',
#               '#98df8a',
#               '#c49c94',
#               '#7f7f7f',
#               '#ff7f0e',
#               '#f7b6d2',
#               '#9467bd',
#               '#7f7f7f',
#               '#8c564b',
#               '#ff7f0e',
#               '#e377c2',
#               '#9467bd',
#               '#c7c7c7',
#               '#98df8a',
#               '#e377c2',
#               '#f7b6d2',
#               '#7f7f7f',
#               '#1f77b4',
#               '#c7c7c7',
#               '#9467bd',
#               '#7f7f7f',
#               '#c7c7c7',
#               '#e377c2',
#               '#8c564b',
#               '#c7c7c7',
#               '#9edae5',
#               '#7f7f7f',
#               '#7f7f7f',
#               '#98df8a',
#               '#7f7f7f',
#               '#c7c7c7',
#               '#f7b6d2',
#               '#9edae5',
#               '#17becf',
#               '#e377c2',
#               '#ffbb78',
#               '#2ca02c',
#               '#e377c2',
#               '#17becf',
#               '#9467bd',
#               '#ff9896',
#               '#c7c7c7',
#               '#e377c2',
#               '#8c564b',
#               '#17becf',
#               '#e377c2',
#               '#e377c2',
#               '#9467bd',
#               '#9467bd',
#               '#ff7f0e',
#               '#8c564b',
#               '#e377c2',
#               '#f7b6d2',
#               '#9467bd',
#               '#9467bd',
#               '#c7c7c7',
#               '#7f7f7f',
#               '#7f7f7f',
#               '#aec7e8',
#               '#f7b6d2',
#               '#8c564b',
#               '#e377c2',
#               '#1f77b4',
#               '#98df8a',
#               '#8c564b',
#               '#e377c2',
#               '#9edae5',
#               '#98df8a',
#               '#c7c7c7',
#               '#7f7f7f',
#               '#c7c7c7',
#               '#98df8a',
#               '#aec7e8',
#               '#7f7f7f',
#               '#c7c7c7',
#               '#7f7f7f',
#               '#e377c2',
#               '#17becf',
#               '#17becf',
#               '#ffbb78',
#               '#1f77b4',
#               '#98df8a',
#               '#e377c2',
#               '#7f7f7f',
#               '#9467bd',
#               '#8c564b',
#               '#ff7f0e',
#               '#7f7f7f',
#               '#e377c2',
#               '#8c564b',
#               '#7f7f7f',
#               '#c7c7c7',
#               '#e377c2',
#               '#c7c7c7',
#               '#ff7f0e',
#               '#9467bd',
#               '#7f7f7f',
#               '#9467bd',
#               '#8c564b',
#               '#7f7f7f',
#               '#bcbd22',
#               '#e377c2',
#               '#e377c2',
#               '#9467bd',
#               '#17becf',
#               '#9edae5',
#               '#e377c2',
#               '#bcbd22',
#               '#e377c2',
#               '#dbdb8d',
#               '#7f7f7f',
#               '#c49c94',
#               '#8c564b',
#               '#e377c2',
#               '#98df8a',
#               '#7f7f7f',
#               '#e377c2',
#               '#c7c7c7',
#               '#9edae5',
#               '#9467bd',
#               '#e377c2',
#               '#8c564b',
#               '#c7c7c7',
#               '#ffbb78',
#               '#9467bd',
#               '#bcbd22',
#               '#9467bd',
#               '#dbdb8d',
#               '#8c564b',
#               '#f7b6d2',
#               '#c7c7c7',
#               '#e377c2',
#               '#8c564b',
#               '#7f7f7f',
#               '#ff7f0e',
#               '#bcbd22',
#               '#c7c7c7',
#               '#c49c94',
#               '#9edae5',
#               '#9467bd',
#               '#9467bd',
#               '#e377c2',
#               '#e377c2',
#               '#f7b6d2',
#               '#e377c2',
#               '#9467bd',
#               '#e377c2',
#               '#c7c7c7',
#               '#c7c7c7',
#               '#9edae5',
#               '#e377c2',
#               '#c5b0d5',
#               '#7f7f7f',
#               '#ff7f0e',
#               '#98df8a',
#               '#7f7f7f',
#               '#9467bd',
#               '#c7c7c7',
#               '#d62728',
#               '#17becf',
#               '#9467bd',
#               '#7f7f7f',
#               '#8c564b',
#               '#bcbd22',
#               '#e377c2',
#               '#c7c7c7',
#               '#9467bd',
#               '#ffbb78',
#               '#e377c2',
#               '#9467bd',
#               '#e377c2',
#               '#c5b0d5',
#               '#c7c7c7',
#               '#9467bd',
#               '#1f77b4',
#               '#98df8a',
#               '#c7c7c7',
#               '#ffbb78',
#               '#c7c7c7',
#               '#98df8a',
#               '#e377c2',
#               '#dbdb8d',
#               '#98df8a',
#               '#9467bd',
#               '#c7c7c7',
#               '#c49c94',
#               '#c7c7c7',
#               '#f7b6d2',
#               '#f7b6d2',
#               '#bcbd22',
#               '#bcbd22',
#               '#f7b6d2',
#               '#9467bd',
#               '#c7c7c7',
#               '#c7c7c7',
#               '#c49c94',
#               '#7f7f7f',
#               '#f7b6d2',
#               '#e377c2',
#               '#98df8a',
#               '#e377c2',
#               '#9467bd',
#               '#7f7f7f',
#               '#e377c2',
#               '#c7c7c7',
#               '#9edae5',
#               '#e377c2',
#               '#7f7f7f',
#               '#e377c2',
#               '#f7b6d2',
#               '#9467bd',
#               '#9467bd',
#               '#bcbd22',
#               '#c7c7c7',
#               '#c7c7c7',
#               '#9467bd',
#               '#f7b6d2',
#               '#98df8a',
#               '#17becf',
#               '#e377c2',
#               '#9467bd',
#               '#c7c7c7',
#               '#c7c7c7',
#               '#7f7f7f',
#               '#c7c7c7',
#               '#98df8a',
#               '#7f7f7f',
#               '#7f7f7f',
#               '#9467bd',
#               '#ffbb78',
#               '#c49c94',
#               '#f7b6d2',
#               '#98df8a',
#               '#7f7f7f',
#               '#9467bd',
#               '#7f7f7f',
#               '#9467bd',
#               '#7f7f7f',
#               '#ff7f0e',
#               '#9467bd',
#               '#e377c2',
#               '#c7c7c7',
#               '#c7c7c7',
#               '#1f77b4',
#               '#7f7f7f',
#               '#f7b6d2',
#               '#8c564b',
#               '#9467bd',
#               '#e377c2',
#               '#ffbb78',
#               '#c7c7c7',
#               '#17becf',
#               '#9467bd',
#               '#8c564b',
#               '#ff9896',
#               '#c7c7c7',
#               '#9467bd',
#               '#8c564b',
#               '#7f7f7f',
#               '#ffbb78',
#               '#8c564b',
#               '#c7c7c7',
#               '#f7b6d2',
#               '#7f7f7f',
#               '#9edae5',
#               '#9467bd',
#               '#9edae5',
#               '#17becf',
#               '#e377c2',
#               '#ff7f0e',
#               '#f7b6d2',
#               '#f7b6d2',
#               '#9467bd',
#               '#17becf',
#               '#dbdb8d',
#               '#e377c2',
#               '#c7c7c7',
#               '#7f7f7f',
#               '#e377c2',
#               '#7f7f7f',
#               '#9edae5',
#               '#c7c7c7',
#               '#c49c94',
#               '#f7b6d2',
#               '#c7c7c7',
#               '#17becf',
#               '#aec7e8',
#               '#e377c2',
#               '#c49c94',
#               '#8c564b',
#               '#9467bd',
#               '#1f77b4',
#               '#7f7f7f',
#               '#dbdb8d',
#               '#9467bd',
#               '#ffbb78',
#               '#e377c2',
#               '#ff7f0e',
#               '#c7c7c7',
#               '#98df8a',
#               '#9467bd',
#               '#9467bd',
#               '#ff7f0e',
#               '#ffbb78',
#               '#7f7f7f',
#               '#ffbb78',
#               '#f7b6d2',
#               '#7f7f7f',
#               '#bcbd22',
#               '#17becf',
#               '#7f7f7f',
#               '#e377c2',
#               '#9467bd',
#               '#9467bd',
#               '#f7b6d2',
#               '#9467bd',
#               '#c7c7c7',
#               '#9467bd',
#               '#9467bd',
#               '#1f77b4',
#               '#c7c7c7',
#               '#e377c2',
#               '#9467bd',
#               '#7f7f7f',
#               '#17becf',
#               '#9467bd',
#               '#c7c7c7',
#               '#9467bd',
#               '#7f7f7f',
#               '#2ca02c',
#               '#c7c7c7',
#               '#ff7f0e',
#               '#9467bd',
#               '#9467bd',
#               '#e377c2',
#               '#7f7f7f',
#               '#c7c7c7',
#               '#9467bd',
#               '#7f7f7f',
#               '#8c564b',
#               '#9467bd',
#               '#c7c7c7',
#               '#9467bd',
#               '#ff7f0e',
#               '#c7c7c7',
#               '#9467bd',
#               '#bcbd22',
#               '#17becf',
#               '#f7b6d2',
#               '#e377c2',
#               '#f7b6d2',
#               '#9467bd',
#               '#c7c7c7',
#               '#9edae5',
#               '#e377c2',
#               '#f7b6d2',
#               '#e377c2',
#               '#bcbd22',
#               '#7f7f7f',
#               '#9467bd',
#               '#e377c2',
#               '#9467bd',
#               '#c7c7c7',
#               '#bcbd22',
#               '#c7c7c7',
#               '#9467bd',
#               '#e377c2',
#               '#9467bd',
#               '#9467bd',
#               '#f7b6d2',
#               '#9467bd',
#               '#c7c7c7',
#               '#9edae5',
#               '#e377c2',
#               '#7f7f7f',
#               '#98df8a',
#               '#98df8a',
#               '#e377c2',
#               '#8c564b',
#               '#8c564b',
#               '#9467bd',
#               '#ff7f0e',
#               '#dbdb8d',
#               '#9467bd',
#               '#9467bd',
#               '#9467bd',
#               '#7f7f7f',
#               '#c7c7c7',
#               '#9467bd',
#               '#8c564b',
#               '#c7c7c7',
#               '#c7c7c7',
#               '#8c564b',
#               '#e377c2',
#               '#17becf',
#               '#17becf',
#               '#98df8a',
#               '#8c564b',
#               '#aec7e8',
#               '#f7b6d2',
#               '#ffbb78',
#               '#2ca02c',
#               '#2ca02c',
#               '#c7c7c7',
#               '#8c564b',
#               '#f7b6d2',
#               '#17becf',
#               '#c7c7c7',
#               '#7f7f7f',
#               '#98df8a',
#               ...]},
#             js_event_callbacks={},
#             js_property_callbacks={},
#             name=None,
#             selected=bokeh.models.selections.Selection(
#                 id='687d8713-2189-4f9e-9eab-12940e2da563',
#                 indices=[],
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 line_indices=[],
#                 multiline_indices={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             selection_policy=bokeh.models.selections.UnionRenderers(
#                 id='e87696ba-02cd-46bb-ad2e-50b7d292fbbe',
#                 js_event_callbacks={},
#                 js_property_callbacks={},
#                 name=None,
#                 subscribed_events=[],
#                 tags=[]),
#             subscribed_events=[],
#             tags=[]),
#         subscribed_events=[],
#         tags=[]),
#     visible=True,
#     x_range_name='default',
#     y_range_name='default')

# %%
show(plot_lda)
# Out:
#   <div class="bk-root" id="4c648f88-6e7b-4401-9a11-2cddab106b4f"></div>

# %%
# plot the crucial words for each topic
# randomly choose a news (within a topic) coordinate as the crucial words coordinate
topic_coord = np.empty((X_topics.shape[1], 2)) * np.nan
for topic_num in _lda_keys:
  if not np.isnan(topic_coord).any():
    break
  topic_coord[topic_num] = tsne_lda[_lda_keys.index(topic_num)]

# plot crucial words
for i in range(X_topics.shape[1]):
  plot_lda.text(topic_coord[i, 0], topic_coord[i, 1], [topic_summaries[i]])

# hover tools
hover = plot_lda.select(dict(type=HoverTool))
hover.tooltips = {"content": "@content - topic: @topic_key"}

# save the plot
#save(plot_lda, '{}.html'.format(title))
show(plot_lda)
# Out:
#   <div class="bk-root" id="0a75660d-7c38-41a8-bd15-3fb077db2b46"></div>

# %% [markdown]
# ### Ref:
# https://shuaiw.github.io/2016/12/22/topic-modeling-and-tsne-visualzation.html
